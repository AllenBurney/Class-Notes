# %% [markdown]
# # Introduction to Plotting

# %% [markdown]
# *Data visualization is a part of the data preprocessing step as well as the data presentation step.*

# %% [markdown]
# What is the need to visualize data when there are numerical values already present?
# - Easier to compare plotted values than numeric values.
# - Gain better intuition of the data than would be possible by looking at tables of values alone.
# - Hidden patterns may get highlighted which may be used later for model selection.

# %% [markdown]
# How do we visualize data in Python?
# - Mainly done using libraries such as matplotlib and seaborn where seaborn is built on top of matplotlib.
# - Using seaborn library, a lot can be achieved with the help of fewer lines of code.

# %% [markdown]
# ## About the dataset

# %% [markdown]
# - Anscombe dataset (also known as Anscombe's quartet).
# - Created by English statistician Frank Anscombe.
# - Purpose is to show the importance of statistical graphs, thereby showing the importance of visualization.
# - Contains four sets of data, each of which contains two continuous variables.
# - Each set has the same values of statistical measures.
# - However, data visualization reveals that each set does not follow the same pattern.
# - Pitfalls of looking at only summary statistics are also highlighted.
# - Such is the popularity of the dataset that it is built into the seaborn library.

# %% [markdown]
# ## Fetching the dataset

# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df_anscombe = sns.load_dataset("anscombe")

# %% [markdown]
# ## Getting a glimpse of the dataset

# %%
print(type(df_anscombe))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df_anscombe.columns)
# Out:
# Index(['dataset', 'x', 'y'], dtype='object')

# %%
print(df_anscombe.dtypes)
# Out:
# dataset     object
# x          float64
# y          float64
# dtype: object

# %%
print(df_anscombe.shape)
# Out:
# (44, 3)

# %%
print(df_anscombe.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 44 entries, 0 to 43
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   dataset  44 non-null     object
#  1   x        44 non-null     float64
#  2   y        44 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.2+ KB
# None

# %%
print(df_anscombe.describe())
# Out:
#                x          y
# count  44.000000  44.000000
# mean    9.000000   7.500682
# std     3.198837   1.958925
# min     4.000000   3.100000
# 25%     7.000000   6.117500
# 50%     8.000000   7.520000
# 75%    11.000000   8.747500
# max    19.000000  12.740000

# %%
df_anscombe.sample(6)
# Out:
#    dataset     x      y
# 1        I   8.0   6.95
# 25     III   9.0   7.11
# 7        I   4.0   4.26
# 24     III  13.0  12.74
# 16      II  14.0   8.10
# 3        I   9.0   8.81

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# *The pyplot is a subpackage under the matplotlib package containing all the plotting utilities.*

# %% [markdown]
# ## Basic Plots

# %%
# dividing the dataset into 4 parts

df_anscombe_1 = df_anscombe[df_anscombe['dataset'] == 'I']

# %%
df_anscombe_2 = df_anscombe[df_anscombe['dataset'] == 'II']
df_anscombe_3 = df_anscombe[df_anscombe['dataset'] == 'III']
df_anscombe_4 = df_anscombe[df_anscombe['dataset'] == 'IV']

# %%
# plotting lines from dataset I
# plt.plot allows only numerical values to be plotted

plt.plot(df_anscombe_1['x'], df_anscombe_1['y'])
plt.show()

# %%
# plotting circles from dataset I (popularly knowns as?)

plt.plot(df_anscombe_1['x'], df_anscombe_1['y'], 'o')
plt.show()

# %% [markdown]
# **DIY**: *Do the same for the remaining subsets of anscombe: df_anscombe_2, df_anscombe_3, df_anscombe_4*

# %% [markdown]
# *Any drawback?*

# %%
plt.plot(df_anscombe_2['x'], df_anscombe_2['y'],'--')
plt.show()

# %%
plt.plot(df_anscombe_3['x'], df_anscombe_3['y'])
plt.show()

# %%
plt.plot(df_anscombe_4['x'], df_anscombe_4['y'],c='r')
plt.show()

# %% [markdown]
# ## Basic subplots

# %% [markdown]
# *Instead of creating individual plots, it is better to create subplots in a single figure. Less code, more compact.*

# %%
# defining the plotting area is the first step
figure1 = plt.figure()

# need 4 subplots inside the main figure
# numbered left-to-right, top-to-bottom starting from 1

# subplot location 1 (figure 1, subplot 1; so two 1s in variable name)
axes11 = figure1.add_subplot(2, 2, 1)

# subplot location 2
axes12 = figure1.add_subplot(2, 2, 2)

# subplot location 3
axes13 = figure1.add_subplot(2, 2, 3)

# subplot location 4
axes14 = figure1.add_subplot(2, 2, 4)

# Use the plot method on each axis to create subplots and as a result the entire plot
axes11.plot(df_anscombe_1['x'], df_anscombe_1['y'], 'o')
axes12.plot(df_anscombe_2['x'], df_anscombe_2['y'], 'o')
axes13.plot(df_anscombe_3['x'], df_anscombe_3['y'], 'o')
axes14.plot(df_anscombe_4['x'], df_anscombe_4['y'], 'o')

# Add title to each subplot
axes11.set_title("First dataset")
axes12.set_title("Second dataset")
axes13.set_title("Third dataset")
axes14.set_title("Fourth dataset")

# Add X-axis label to each subplot
axes11.set_xlabel("X")
axes12.set_xlabel("X")
axes13.set_xlabel("X")
axes14.set_xlabel("X")

# Add Y-axis label to each subplot
axes11.set_ylabel("Y")
axes12.set_ylabel("Y")
axes13.set_ylabel("Y")
axes14.set_ylabel("Y")

# Add title to the entire figure (plot)
figure1.suptitle("Anscombe data")

# The axes should be spread apart from one another
figure1.tight_layout()

# %%
df_anscombe_1.describe().loc[['mean', 'std']].apply(lambda z: round(z, 2))
# Out:
#          x     y
# mean  9.00  7.50
# std   3.32  2.03

# %%
df_anscombe_2.describe().loc[['mean', 'std']].apply(lambda z: round(z, 2))
# Out:
#          x     y
# mean  9.00  7.50
# std   3.32  2.03

# %%
df_anscombe_3.describe().loc[['mean', 'std']].apply(lambda z: round(z, 2))
# Out:
#          x     y
# mean  9.00  7.50
# std   3.32  2.03

# %%
df_anscombe_4.describe().loc[['mean', 'std']].apply(lambda z: round(z, 2))
# Out:
#          x     y
# mean  9.00  7.50
# std   3.32  2.03

# %% [markdown]
# *The Anscombe data visualizations illustrate why just looking at summary statistic values can be misleading. It is clear from the above code cell outputs that though each dataset has the same summary statistic values such as mean and standard deviation, the relationship between points vastly differ across the datasets.*

# %% [markdown]
# ## Statistical Graphics

# %% [markdown]
# About the dataset
# - Tips dataset
# - Available in seaborn
# - Contains the tips paid by customers and various variables such as total cost of bill,  day of the week, etc.

# %%
df_tips = sns.load_dataset("tips")

# %%
df_tips.sample(6)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 81        16.66  3.40    Male     No  Thur   Lunch     2
# 142       41.19  5.00    Male     No  Thur   Lunch     5
# 26        13.37  2.00    Male     No   Sat  Dinner     2
# 86        13.03  2.00    Male     No  Thur   Lunch     2

# %%
df_tips.shape
# Out:
# (244, 7)

# %%
df_tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
print(df_tips.dtypes)
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
print(type(df_tips))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
df_tips.describe(include=['category'])
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
df_tips.describe(exclude=['category'])
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
df_tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df_tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %% [markdown]
# ### Univariate plots

# %% [markdown]
# *In Statistics, the term "univariate" refers to a single variable.*

# %% [markdown]
# #### Histogram

# %% [markdown]
# *This is the most common means of looking at a single variable.*

# %%
# defining the plotting area is the first step
fig2 = plt.figure()

# adding a subplot to the created figure
axes21 = fig2.add_subplot(1, 1, 1)

# plotting a histogram in the subplot of the figure
bin_density, bin_edge_values, patches = axes21.hist(df_tips['total_bill'], bins=10)

# showing all the intervals (bins)
plt.xticks(bin_edge_values, rotation=45)

# setting the title of the histogram
axes21.set_title('Histogram of total bill')

# setting the X-axis label; the variable whose frequency is to be found
axes21.set_xlabel("Total bill")

# setting the Y-axis label; the frequency itself
axes21.set_ylabel("Frequency")

# displaying the figure containing the subplot with the histogram
fig2.show()

# saving the figure as a vector graphic with high resolution for later usage
fig2.savefig("Histogram of total bill.svg", format='svg', dpi=300)

# %%
# number of values in each group / interval / bin
# OR
# frequency of each bin
print(bin_density)
# Out:
# [ 7. 42. 68. 51. 31. 19. 12.  7.  3.  4.]

# %% [markdown]
# **Interpretation**: *The histogram shows a right-skewed distribution of total bills, with most bills concentrated in the lower to mid range (around $10–20) and relatively few high-value bills.*

# %%
# same histogram plot using seaborn
# creating a figure and adding a subplot to the figure using a single line of code
# control entire figure details using fig3
# control subplot details using ax31

fig3, axes31 = plt.subplots()

axes31 = sns.histplot(df_tips['total_bill'])  # not specifying bins?
axes31.set_title("Histogram of total bill")
axes31.set_xlabel("Total bill")
axes31.set_ylabel("Frequency")

plt.show()

# %% [markdown]
# **DIY**: *Plot a histogram of size of the party and give an interpretation of the same.*

# %% [markdown]
# #### Density plot (KDE: Kernel Density Estimation)

# %% [markdown]
# *Used for univariate plotting where normal distributions are drawn centered by each data point and then smoothing out the overlapping plots so that the area under the curve is 1.*

# %%
fig4, axes41 = plt.subplots()

axes41 = sns.kdeplot(df_tips['total_bill'])
axes41.set_xlabel("Total bill")
axes41.set_ylabel("Density")
axes41.set_title("KDE plot of total bill")

plt.show()

# %% [markdown]
# #### Histogram with KDE plot

# %%
fig5, axes51 = plt.subplots()

axes51 = sns.histplot(df_tips['total_bill'], kde=True, stat='density', )
axes51.set_xlabel("Total bill")
axes51.set_ylabel("Normalized frequency")
axes51.set_title("Histogram with KDE plot")

plt.show()

# %% [markdown]
# *The KDE is re-estimated and rescaled differently depending on the plotting context. Hence, small differences can appear.*

# %% [markdown]
# #### Count plot (❌ Bar plot ❌)

# %% [markdown]
# *Used for univariate plotting to count discrete variables; often considered a special case of bar plot.*

# %%
fig6, axes61 = plt.subplots()

# pass only x OR y, depending on the orientation of the bars
axes61 = sns.countplot(x='day', data=df_tips, ax=axes61)

axes61.set_title("Count of days of visits to the restaurant")
axes61.set_xlabel("Day of the week")
axes61.set_ylabel("Frequency")

plt.show()

# %% [markdown]
# **Interpretation**: *Most visits were on weekends.*

# %% [markdown]
# ### Bivariate

# %% [markdown]
# *In Statistics, the term "bivariate" refers to two variables.*

# %% [markdown]
# #### Scatter plot

# %% [markdown]
# *Scatter plots are used when a continuous variable is plotted against another continuous variable.*

# %%
# defining the plotting area is the first step
figure7 = plt.figure()

# adding a subplot to the plotting area
axes71 = figure7.add_subplot(1, 1, 1)

# creating a scatter plot in the subplot of the figure
axes71.scatter(df_tips['total_bill'], df_tips['tip'])

# assigning a title to the scatter plot
axes71.set_title("Scatter plot of tip vs total bill")

# giving X-axis and Y-axis labels
axes71.set_xlabel("Total bill")
axes71.set_ylabel("Tip")

# displaying the figure containing the scatter plot
figure7.show()

# saving the figure for later use
figure7.savefig("scatter_plot.svg", format="svg", dpi=300)

# %% [markdown]
# **Interpretation**: *The scatter plot shows a positive relationship between total bill and tip, indicating that as the total bill increases, the tip generally increases as well, though with some variability.*

# %%
fig8, axes81 = plt.subplots()

axes81 = sns.regplot(x='total_bill', y='tip', data=df_tips, fit_reg=False, ax=axes81)
axes81.set_title("Scatter plot of Tip versus Total bill")
axes81.set_xlabel("Total bill")
axes81.set_ylabel("Tip")

plt.show()

# %% [markdown]
# **DIY**: *Implement a scatter plot of tip versus number of guests.*

# %% [markdown]
# #### Bar plot

# %% [markdown]
# *Bar plots can also be used to plot bivariate distributions.*

# %%
fig9, axes91 = plt.subplots()

axes91 = sns.barplot(x='time', y='total_bill', data=df_tips, ax=axes91)
axes91.set_title("Bar plot of average total bill for time of day")
axes91.set_xlabel("Time of day")
axes91.set_ylabel("Average total bill")

plt.show()

# %% [markdown]
# **Interpretation**: *The bar plot shows that the average total bill is higher at Dinner than at Lunch, indicating customers tend to spend more in the evening. The error bars or whiskers (confidence intervals) show some variability in spending, with Lunch having slightly higher relative variability, but the intervals are clearly separated—suggesting the difference in average spending between Lunch and Dinner is meaningful, not just random noise.*

# %% [markdown]
# #### Box plot

# %% [markdown]
# *Box plots are used when a discrete variable is plotted against a continuous variable.*

# %%
# defining the plotting area is the first step
figure4 = plt.figure()

axes41 = figure4.add_subplot(1, 1, 1)

# data has to be passed as a list; tip paid by female customers and tip paid by male customers
axes41.boxplot([df_tips[df_tips['sex']=='Female']['tip'], df_tips[df_tips['sex']=='Male']['tip']],
               tick_labels = ['Female', 'Male'])

axes41.set_xlabel('Gender of the tip provider')
axes41.set_ylabel('Tip')

axes41.set_title('Box plot of tips paid with respect to gender')

figure4.show()

figure4.savefig("boxplot.svg", format="svg", dpi=300)

# %% [markdown]
# **Interpretation**:
# - The box plot shows the central tendency, spread, and presence of outliers in the data.
# - The orange line denotes the second quartile (Q2) or 50th percentile of the data; also known as median.
# - The lower edge of the box denotes first quartile (Q1) or 25th percentile of the data.
# - The upper edge of the box denotes third quartile (Q3) or 75th percentile of the data.
# - The interquartile range (IQR) is given by the difference of Q3 and Q1.
# - The whisker towards the lower edge denotes the smallest value which is not an outlier.
# - The whisker towards the upper edge denotes the highest value which is not an outlier.
# - The points beyond the whisker towards the upper edge highlight the presence of outliers, suggesting extreme values that deviate significantly from the majority of the data.

# %% [markdown]
# **DIY**: *Code a box plot to show the variability of tip with respect to the time of the day when the order was placed.*
